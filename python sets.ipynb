# %%
# Set => {} , unique items , set , un ordered , no indexing , no duplicate , mutble
job_skills = {'python','sql','statistics' , 'tableau'}

# %%
job_skills
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set(iterable=(), /)
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(self, object, /)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
# ...

# %%
# add from start 
job_skills.add('looker') 
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
# reomve item 
job_skills.pop()
job_skills
# Out:
# {'looker', 'sql', 'statistics', 'tableau'}

# %%
job_skills.remove('tableau')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 job_skills.remove('tableau')
#       2 job_skills
#
# KeyError: 'tableau'

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics'}
